# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set_theme()
import matplotlib.pyplot as plt

# %%
! scp rasa:~/Egor/proj/gpu/out.csv gpu_csv.csv
# Out:
# out.csv                                       100% 9725KB   3.1MB/s   00:03

# %%
data = pd.read_csv("gpu_csv.csv")
fig, ax = plt.subplots(figsize=(10, 8))  
ax = sns.heatmap(data,yticklabels = False, xticklabels = False,  cmap="YlGnBu", ax=ax)

# %%
fig.savefig('1.png')
